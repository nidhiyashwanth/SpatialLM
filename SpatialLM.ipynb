# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhiyashwanth/SpatialLM/blob/main/SpatialLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Mar 23 05:11:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/manycore-research/SpatialLM.git
# %cd SpatialLM
# Out:
# Cloning into 'SpatialLM'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 68 (delta 3), reused 3 (delta 3), pack-reused 59 (from 1)
# Receiving objects: 100% (68/68), 6.37 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/SpatialLM

# %%
# !pip install poetry
# !poetry config virtualenvs.create false --local
# !poetry install
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 kB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# ...
# Skipping virtualenv creation, as specified in config file.
# Updating dependencies
# ...

# %%
# !poe install-torchsparse
# Out:
# Poe => pip install git+https://github.com/mit-han-lab/torchsparse.git
# Skipping virtualenv creation, as specified in config file.
# ...
#   Cloning https://github.com/mit-han-lab/torchsparse.git to /tmp/pip-req-build-4tkj3b7z
#   Running command git clone --filter=blob:none --quiet https://github.com/mit-han-lab/torchsparse.git /tmp/pip-req-build-4tkj3b7z
#   Resolved https://github.com/mit-han-lab/torchsparse.git to commit 385f5ce8718fcae93540511b7f5832f4e71fd835
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached backports.cached_property-1.0.2-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached rootpath-0.1.1-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached colour_runner-0.1.1-py2.py3-none-any.whl.metadata (828 bytes)
# ...
#   Using cached deepdiff-8.4.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached tox-4.24.2-py3-none-any.whl.metadata (3.7 kB)
# ...

# %%
# Will build and install torchsparse myself
# !git clone https://github.com/mit-han-lab/torchsparse.git
# %cd torchsparse
# Out:
# Cloning into 'torchsparse'...
# remote: Enumerating objects: 1277, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 1277 (delta 8), reused 6 (delta 3), pack-reused 1245 (from 2)
# Receiving objects: 100% (1277/1277), 1.50 MiB | 3.66 MiB/s, done.
# Resolving deltas: 100% (591/591), done.
# /content/SpatialLM/torchsparse

# %%
# !sed -i 's/11\.0/12.4/g' setup.py

# %%
# !apt-get update && apt-get install -y libsparsehash-dev
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !python setup.py bdist_wheel
# Out:
# torchsparse version: 2.1.0
# running bdist_wheel
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:495: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running build
# running build_py
# copying torchsparse/__init__.py -> build/lib.linux-x86_64-cpython-311/torchsparse
# copying torchsparse/version.py -> build/lib.linux-x86_64-cpython-311/torchsparse
# copying torchsparse/backends.py -> build/lib.linux-x86_64-cpython-311/torchsparse
# copying torchsparse/operators.py -> build/lib.linux-x86_64-cpython-311/torchsparse
# copying torchsparse/tensor.py -> build/lib.linux-x86_64-cpython-311/torchsparse
# copying torchsparse/backbones/unet.py -> build/lib.linux-x86_64-cpython-311/torchsparse/backbones
# copying torchsparse/backbones/__init__.py -> build/lib.linux-x86_64-cpython-311/torchsparse/backbones
# ...

# %%
# !pip install dist/*.whl
# Out:
# Processing ./dist/torchsparse-2.1.0-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached backports.cached_property-1.0.2-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached rootpath-0.1.1-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached colour_runner-0.1.1-py2.py3-none-any.whl.metadata (828 bytes)
# ...
#   Using cached deepdiff-8.4.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached tox-4.24.2-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached coverage-7.7.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# ...
#   Using cached codecov-2.1.13-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached blessings-1.7-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached orderly_set-5.3.0-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# ...

# %%
# %cd ..
# Out:
# /content/SpatialLM

# %%
# !pip install huggingface_hub
# !huggingface-cli download manycore-research/SpatialLM-Testset pcd/scene0000_00.ply --repo-type dataset --local-dir .
# Out:
# ...
# WARNING: Error parsing dependencies of spatiallm: Local version label can only be used with `==` or `!=` operators
#     torch (>=2.4.1+cu124,<3.0.0)
#            ~~~~~~~^
# ...
# scene0000_00.ply: 100% 11.0M/11.0M [00:00<00:00, 49.1MB/s]
# Download complete. Moving file to pcd/scene0000_00.ply
# pcd/scene0000_00.ply

# %%
# !python inference.py --point_cloud pcd/scene0000_00.ply --output scene0000_00.txt --model_path manycore-research/SpatialLM-Llama-1B
# Out:
# 2025-03-23 06:48:14.512060: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742712494.773317   28618 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742712494.845250   28618 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 06:48:15.404992: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python visualize.py --point_cloud pcd/scene0000_00.ply --layout scene0000_00.txt --save scene0000_00.rrd
# Out:
# 2025-03-23 06:51:22.518320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742712682.546039   29441 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742712682.554727   29441 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 06:51:22.591519: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !rerun scene0000_00.rrd
# Out:
# Error: winit EventLoopError: os error at /usr/local/cargo/registry/src/index.crates.io-6f17d22bba15001f/winit-0.30.7/src/platform_impl/linux/mod.rs:764: neither WAYLAND_DISPLAY nor WAYLAND_SOCKET nor DISPLAY is set.

# %%
# !apt-get install -y xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 30 not upgraded.
# Need to get 7,814 kB of archives.
# After this operation, 12.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# ...

# %%
# !xvfb-run -a python visualize.py --point_cloud pcd/scene0000_00.ply --layout scene0000_00.txt --save scene0000_00.rrd
# Out:
# 2025-03-23 06:54:36.621301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742712876.642266   30457 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742712876.648735   30457 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 06:54:36.670554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !rerun scene0000_00.rrd
# Out:
# Error: winit EventLoopError: os error at /usr/local/cargo/registry/src/index.crates.io-6f17d22bba15001f/winit-0.30.7/src/platform_impl/linux/mod.rs:764: neither WAYLAND_DISPLAY nor WAYLAND_SOCKET nor DISPLAY is set.
